# %% [markdown]
# # Full Report
#
# With some text and description.
#
# Maybe some bullet points:
# * bullet 1
# * bullet 2
#
#
# Or some numbered lists:
# 1. one
# 1. two
# 1. three

# %%
import pandas as pd

import chart_utils
import utils

from IPython.display import Markdown, HTML

# Default parameters
fulldate_format = utils.fulldate_format
time_zone = utils.time_zone
start_date = utils.start_date
two_weeks_ago = utils.two_weeks_ago

# Import data
df = utils.clean_jhu()

chart_utils.make_chart(df, "Los Angeles", "8/1/20")
# Out:
# alt.LayerChart(...)

# %%
# Import data
#df = utils.clean_jhu()

# %%
"""
for c in ca_counties:
    id_anchor = c.replace(" - ", "-").replace(" ", "-")

    display(HTML(f"<a id={id_anchor}></a>"))
    plot_charts(jhu, hospitalizations, c)
    display(HTML(
        "<br>"
        "<a href=#counties_by_region>Return to top</a><br>"
    ))
"""
